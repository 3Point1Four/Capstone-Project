# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('path to dataset file')

for i in range(26):
    plot_variable_name = f"plot_data_{i}"
    dd = data[data['0'] == i].iloc[1]
    x = dd[1:].values
    x = x.reshape((28,28))
    plt.axis('off')  # Turn off both x and y axes
    plt.imshow(x, cmap = 'binary')
    plt.show
    output_file_name = f"output_plot_{i}.png"
    plt.savefig(output_file_name, format='png')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = pd.read_csv('C:\\Users\\Pirann\\.vscode\\archive\\A_Z Handwritten Data.csv')
#       3 for i in range(26):
#       4     plot_variable_name = f"plot_data_{i}"
#
# ...
